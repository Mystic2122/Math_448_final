# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt

# %%
df = pd.read_json("NBA_player_data.json")

# %%
#Replaces position names with numbers
position_mapping = {"PG": 1, "SG": 2, "SF": 3, "PF": 4, "C": 5}
df["Pos"] = df["Pos"].map(position_mapping)

# %%
positions = {1:"PG", 2:"SG", 3:"SF", 4:"PF", 5:"C"}

# %%
#Points
ppg_by_pos = [df[df['Pos'] == pos]['PTS'] for pos in positions]

# Plotting
plt.boxplot(ppg_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average PPG')
plt.title('Average Points per Game by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Assists
ast_by_pos = [df[df['Pos'] == pos]['AST'] for pos in positions]

# Plotting
plt.boxplot(ast_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average AST')
plt.title('Average Assists per Game by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Rebounds
# Calculate total rebounds by position
total_rbs = [df[df['Pos'] == pos]['TRB'] for pos in positions]

# Plotting
plt.boxplot(total_rbs, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Total Rebounds')
plt.title('Average Total Rebounds per Game by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Blocks
bpg_by_pos = [df[df['Pos'] == pos]['BLK'] for pos in positions]

# Plotting
plt.boxplot(bpg_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average BPG')
plt.title('Average Blocks per Game by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Steals
spg_by_pos = [df[df['Pos'] == pos]['STL'] for pos in positions]

# Plotting
plt.boxplot(spg_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average SPG')
plt.title('Average Steals per Game by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Turnovers
tov_by_pos = [df[df['Pos'] == pos]['TOV'] for pos in positions]

# Plotting
plt.boxplot(tov_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average TOV')
plt.title('Average Turnovers per Game by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Field goal percentage
fgp_by_pos = [df[df['Pos'] == pos]['FG%'] for pos in positions]

# Plotting
plt.boxplot(fgp_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average FG%')
plt.title('Average Field Goal Percentage by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Free throw percentage
ftp_by_pos = [df[df['Pos'] == pos]['FT%'] for pos in positions]

# Plotting
plt.boxplot(ftp_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average FT%')
plt.title('Average Free Throw Percentage by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Personal Fouls
pf_by_pos = [df[df['Pos'] == pos]['PF'] for pos in positions]

# Plotting
plt.boxplot(pf_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average PF')
plt.title('Average Personal Fouls by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()

# %%
#Minutes played
pf_by_pos = [df[df['Pos'] == pos]['MP'] for pos in positions]

# Plotting
plt.boxplot(pf_by_pos, labels=positions.values())
plt.xlabel('Position')
plt.ylabel('Average MP')
plt.title('Average Minutes Played by Position')

# Customize the tick labels on the x-axis
plt.xticks(list(positions.keys()), list(positions.values()))

plt.show()
